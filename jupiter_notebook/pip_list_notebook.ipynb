# %% [markdown]
# Run jupyter notebook:   jupyter notebook C1/W1/ungraded_lab/C1_W1_Lab_1_hello_world_nn.ipynb

# %%
import subprocess

# Execute the pip list command
result = subprocess.run(['pip', 'list'], capture_output=True, text=True)

# Check if the command executed successfully
if result.returncode == 0:
    # Print the output of the pip list command
    print(result.stdout)
else:
    # Print the error message if the command failed
    print(result.stderr)
# Out:
# Package              Version
# -------------------- -----------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# async-timeout        4.0.2
# attrs                21.4.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.1
# boto3                1.24.57
# botocore             1.27.57
# certifi              2022.6.15
# cffi                 1.15.1
# charset-normalizer   2.1.0
# click                8.1.3
# debugpy              1.6.2
# decorator            5.1.1
# defusedxml           0.7.1
# Deprecated           1.2.13
# entrypoints          0.4
# et-xmlfile           1.1.0
# executing            0.8.3
# fastjsonschema       2.16.1
# Flask                2.2.1
# freezegun            1.2.1
# fuzzywuzzy           0.18.0
# gTTS                 2.2.4
# idna                 3.3
# importlib-metadata   4.12.0
# iniconfig            1.1.1
# ipykernel            6.15.1
# ipython              8.4.0
# ipython-genutils     0.2.0
# ipywidgets           7.7.1
# itsdangerous         2.1.2
# jedi                 0.18.1
# Jinja2               3.1.2
# jmespath             0.10.0
# jsonschema           4.7.2
# jupyter-client       7.3.4
# jupyter-console      6.4.4
# jupyter-core         4.11.1
# jupyterlab-pygments  0.2.2
# jupyterlab-widgets   1.1.1
# Levenshtein          0.20.8
# MarkupSafe           2.1.1
# matplotlib-inline    0.1.3
# mistune              0.8.4
# mypy                 0.961
# mypy-extensions      0.4.3
# nbclient             0.6.6
# nbconvert            6.5.0
# nbformat             5.4.0
# nest-asyncio         1.5.5
# notebook             6.4.12
# numpy                1.22.1
# openpyxl             3.0.9
# packaging            21.3
# pandas               1.4.0
# pandocfilters        1.5.0
# parso                0.8.3
# pexpect              4.8.0
# pickleshare          0.7.5
# pip                  23.1.2
# pluggy               1.0.0
# prometheus-client    0.14.1
# prompt-toolkit       3.0.30
# psutil               5.9.1
# ptyprocess           0.7.0
# pure-eval            0.2.2
# py                   1.11.0
# py4j                 0.10.9.2
# pycparser            2.21
# Pygments             2.12.0
# pyparsing            3.0.8
# pyrsistent           0.18.1
# pyspark              3.2.0
# pytest               7.1.1
# pytest-freezegun     0.4.2
# python-dateutil      2.8.2
# python-Levenshtein   0.20.8
# pytz                 2021.3
# pyzmq                23.2.0
# qtconsole            5.3.1
# QtPy                 2.1.0
# rapidfuzz            2.13.6
# redis                4.3.4
# requests             2.28.1
# s3transfer           0.6.0
# Send2Trash           1.8.0
# setuptools           58.1.0
# six                  1.16.0
# soupsieve            2.3.2.post1
# stack-data           0.3.0
# terminado            0.15.0
# time-machine         2.6.0
# tinycss2             1.1.1
# tomli                2.0.1
# tornado              6.2
# traitlets            5.3.0
# typing_extensions    4.3.0
# urllib3              1.26.8
# wcwidth              0.2.5
# webencodings         0.5.1
# Werkzeug             2.2.1
# widgetsnbextension   3.6.1
# wrapt                1.14.1
# zipp                 3.8.1

# %%
import subprocess

# Execute the pip list command
result = subprocess.run(['python',  '-V'], capture_output=True, text=True)

# Check if the command executed successfully
if result.returncode == 0:
    # Print the output of the pip list command
    print(result.stdout)
else:
    # Print the error message if the command failed
    print(result.stderr)

# %%
print("hello from notebook")
